# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
#
# 1. Python - A versatile language with extensive libraries for data analysis and machine learning (NumPy, Pandas, Scikit-learn)
# 2. R - A statistical programming language widely used for data visualization and statistical modeling
# 3. SQL - Essential for querying and managing databases
# 4. Julia - A high-performance language designed for numerical and scientific computing
# 5. Scala - Often used with Apache Spark for big data processing

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
#
# - Pandas
# - NumPy
# - Matplotlib
# - Scikit-learn
# - TensorFlow

# %% [markdown]
# | Data Science Tools |
# |---|
# | Jupyter Notebook |
# | Apache Spark |
# | RStudio |

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python

# %%
# This is a simple arithmetic expression to multiply then add integers
(3*4)+5
# Out:
# 17

# %%
# This will convert 200 minutes to hours by dividing by 60
round(200/60, 2)
# Out:
# 3.33

# %% [markdown]
# **Objectives:**
#
# - Understand the fundamentals of data science
# - Master Python for data analysis
# - Work with Pandas and NumPy libraries
# - Create visualizations with Matplotlib
# - Build and evaluate machine learning models

# %% [markdown]
# ## Author
#
# Kannan Balakrishnan
